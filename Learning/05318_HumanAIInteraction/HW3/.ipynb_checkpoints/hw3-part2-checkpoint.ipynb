# %% [markdown]
# # Homework 3 Part 2 | Frank Yue Ying | yying2

# %%
import pandas as pd
import numpy as np
import sklearn as sk # import scikit-learn
from sklearn import preprocessing # import preprocessing utilites

# %%
df = pd.read_csv("death_causes.csv")
df.columns.values[0] = "id"

# %% [markdown]
# #### Question 1

# %%
df[(df['group'] == "Cancer") & (df['manner'] != "Accident")]
# Out:
#             id  age sex   race  education  month_of_death  \
# 3       782491   77   F  White        3.0               6
# 10     1729618   83   M  White        9.0               4
# 12      111357   88   F  White        1.0               6
# 16     1514870   95   F  White        3.0               9
# 19      904687   84   M  White        6.0              11
# ...        ...  ...  ..    ...        ...             ...
# 99986  2086357   86   M  Black        1.0              10
# 99991   905167   66   F  White        3.0              11
# 99993  1011339   73   F  White        7.0               3
# 99996   611380   63   M  Black        3.0               8
# 99999  2085421   85   M  Black        3.0              10
#
#        day_of_week_of_death          manner relationship_status icd_code  \
# 3                         3  Natural Causes             Widowed      C43
# 10                        2  Natural Causes             Married      C25
# 12                        5  Natural Causes             Widowed      C83
# 16                        7  Natural Causes            Divorced      C23
# 19                        2  Natural Causes             Married      C34
# ...                     ...             ...                 ...      ...
# 99986                     5  Natural Causes             Widowed      C25
# 99991                     7  Natural Causes            Divorced      C64
# 99993                     1  Natural Causes            Divorced      C34
# 99996                     5  Natural Causes            Divorced      C32
# 99999                     5  Natural Causes             Widowed      C85
#
#                                                    cause   group
# 3                         ['Malignant melanoma of skin']  Cancer
# 10                    ['Malignant neoplasm of pancreas']  Cancer
# 12                           ['Non-follicular lymphoma']  Cancer
# 16                 ['Malignant neoplasm of gallbladder']  Cancer
# 19           ['Malignant neoplasm of bronchus and lung']  Cancer
# ...                                                  ...     ...
# 99986                 ['Malignant neoplasm of pancreas']  Cancer
# 99991  ['Malignant neoplasm of kidney, except renal p...  Cancer
# 99993        ['Malignant neoplasm of bronchus and lung']  Cancer
# 99996                   ['Malignant neoplasm of larynx']  Cancer
# 99999  ['Other specified and unspecified types of non...  Cancer
#
# [22871 rows x 12 columns]

# %%
# Referenced from Homework 1: Home_loan_Prediction
def feature_engineering(df):
    features_cat = ['sex', 'race','education','month_of_death','day_of_week_of_death','manner','relationship_status']
    features_num = ['age']
    X_cat = df[features_cat]
    X_num = df[features_num]
    enc = preprocessing.OneHotEncoder()
    enc.fit(X_cat)
    one_hot = enc.transform(X_cat)
    X_cat_proc = pd.DataFrame(one_hot.toarray(), columns=enc.get_feature_names_out())
    scaled = preprocessing.scale(X_num)
    X_num_proc = pd.DataFrame(scaled, columns=features_num)
    df_result = pd.concat([X_num_proc, X_cat_proc], axis=1, sort=False)
    return df_result

# %%
# Model No.1 Predicting Cancer using Linear Regression
from sklearn.linear_model import LinearRegression
df_1 = df.drop(columns=['id', 'icd_code','cause'])
df_1["label"] = np.where(df_1["group"] == "Cancer", 1, 0)
df_1 = df_1.drop(columns=['group'])
X_1 = feature_engineering(df_1)
y_1 = df_1["label"]
model_1 = LinearRegression().fit(X_1, y_1)
