# %%
import requests
import json
import pandas as pd
from pandas import json_normalize

# %% [markdown]
# Reference:
# 1. Guide to use Crunchbase API: https://medium.com/priyanshumadan/extract-data-from-crunchbase-api-using-python-8e99ed6bc73e
# 2. API swaggerhub: https://app.swaggerhub.com/apis-docs/Crunchbase/crunchbase-enterprise_api/1.0.3#/Search/post_searches_organizations
# 3. Basic API attributes; https://data.crunchbase.com/docs/organizationsummary

# %%
base_url = "https://api.crunchbase.com/api/v4"
headers = {
      'user_key': '8c9994bdd405a74ef7f631780c9bdabd',
     'Content-Type': 'application/json'
    }

# %%
# Some of the fields are nt 
payload = {
"field_ids": [
"created_at",
"updated_at",
"entity_def_id",
"facebook",
"facet_ids",
"name",
"twitter",
#"identifier",
"location_identifiers",
"short_description",
"linkedin"#,
#"website"
],
"limit": 1000,
"query": [
{
"type": "predicate",
"field_id": "location_identifiers",
"operator_id": "includes",
"values": [
"4ce61f42-f6c4-e7ec-798d-44813b58856b" #UUID FOR LOS ANGELES
]
},
{
"type": "predicate",
"field_id": "facet_ids",
"operator_id": "includes",
"values": [
"company"
]
}
]
}

# %%
end_points = '/searches/organizations'
response = requests.post(base_url+end_points, params=headers, json=payload)

# %%
result = json.loads(response.text)

# %%
response.status_code
# Out:
# 200

# %%
result
# Out:
# {'count': 17852,
#  'entities': [{'uuid': 'e24eb956-a671-46fe-a04b-d461684f016b',
#    'properties': {'name': 'Blockdaemon',
#     'facet_ids': ['investor', 'company', 'rank'],
#     'identifier': {'permalink': 'blockdaemon',
#      'image_id': 'loofgtnytw5te0ssqlyb',
#      'uuid': 'e24eb956-a671-46fe-a04b-d461684f016b',
#      'entity_def_id': 'organization',
#      'value': 'Blockdaemon'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/blockdaemon'},
#     'short_description': 'Blockdaemon is a blockchain deployment facilitator that manages nodes and payment rails for blockchain networks.',
#     'created_at': '2018-01-30T06:43:59Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/_blockdaemon'},
#     'updated_at': '2022-03-09T12:38:37Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '58a49f48-f049-1150-d215-51ee302ae0dd',
#    'properties': {'name': 'Riot Games',
#     'facet_ids': ['investor', 'company', 'rank'],
#     'identifier': {'permalink': 'riot-games',
#      'image_id': 'aokeyvfmozfn00cuy1xk',
#      'uuid': '58a49f48-f049-1150-d215-51ee302ae0dd',
#      'entity_def_id': 'organization',
#      'value': 'Riot Games'},
#     'linkedin': {'value': 'http://www.linkedin.com/company/riot-games'},
#     'short_description': 'Riot Games is a global company that develops online games.',
#     'facebook': {'value': 'http://www.facebook.com/RiotGamesTurkiye'},
#     'created_at': '2008-07-12T01:53:08Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'http://twitter.com/riotgames'},
#     'updated_at': '2019-01-02T16:42:59Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'e4f41fbf-eea3-2db9-0c69-cd16f5cfc0e9',
#    'properties': {'name': 'Hulu',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'hulu',
#      'image_id': 'bk8cux6dapq8qjzylfaj',
#      'uuid': 'e4f41fbf-eea3-2db9-0c69-cd16f5cfc0e9',
#      'entity_def_id': 'organization',
#      'value': 'Hulu'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/hulu'},
#     'short_description': 'Hulu is an online video service that offers a selection of hit shows, clips, movies, and documentaries through its website. ',
#     'facebook': {'value': 'https://www.facebook.com/hulu/'},
#     'created_at': '2007-08-29T23:07:06Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://www.twitter.com/hulu'},
#     'updated_at': '2019-03-25T20:42:50Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '1e349e9f-1206-6a22-434b-9ca4281a360d',
#    'properties': {'name': 'Bambee',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'bambee',
#      'image_id': 'pctmar5rcej0bdkovnvd',
#      'uuid': '1e349e9f-1206-6a22-434b-9ca4281a360d',
#      'entity_def_id': 'organization',
#      'value': 'Bambee'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/bambee/'},
#     'short_description': 'Bambee is a platform offering an affordable solution to small and medium-sized businesses for hiring HR managers.',
#     'facebook': {'value': 'https://www.facebook.com/bambeeHQ/'},
#     'created_at': '2016-08-31T01:35:49Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/BambeeHQ'},
#     'updated_at': '2022-08-17T17:07:50Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '0f3fd8ce-9fe3-d6bd-d243-ffdf2fcfb012',
#    'properties': {'name': 'StartEngine',
#     'facet_ids': ['investor', 'company', 'rank'],
#     'identifier': {'permalink': 'start-engine',
#      'image_id': 'oxevxb0jcpmjqqrwfurc',
#      'uuid': '0f3fd8ce-9fe3-d6bd-d243-ffdf2fcfb012',
#      'entity_def_id': 'organization',
#      'value': 'StartEngine'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/startengine'},
#     'short_description': 'StartEngine is an equity crowdfunding platform that allows everyday people to invest and own shares in startups and early-stage companies.',
#     'facebook': {'value': 'https://www.facebook.com/StartEngineLA/'},
#     'created_at': '2012-01-17T09:20:52Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/startenginela'},
#     'updated_at': '2022-02-06T01:07:45Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'cb32a4d7-2bd0-1727-a055-63aa6a545380',
#    'properties': {'name': 'VUZ',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': '360vuz',
#      'image_id': 'wksdex48t7zjgrm1sc00',
#      'uuid': 'cb32a4d7-2bd0-1727-a055-63aa6a545380',
#      'entity_def_id': 'organization',
#      'value': 'VUZ'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/360vuz'},
#     'short_description': 'VUZ is a social app that allows users to stream and experience XR and the Metaverse.',
#     'facebook': {'value': 'https://www.facebook.com/360VUZ'},
#     'created_at': '2017-03-11T22:06:30Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/360vuz'},
#     'updated_at': '2022-10-24T04:55:08Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'e6879c14-7f54-1385-f965-493cd450ae99',
#    'properties': {'name': 'Eyenuk',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'eyenuk',
#      'image_id': 'xxe5s9y3usrxbtaps93k',
#      'uuid': 'e6879c14-7f54-1385-f965-493cd450ae99',
#      'entity_def_id': 'organization',
#      'value': 'Eyenuk'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/eyenuk-llc'},
#     'short_description': 'Eyenuk is a medtech company that develops an artificial intelligence screening tool for risk assessment and disease surveillance.',
#     'facebook': {'value': 'https://www.facebook.com/eyenuk'},
#     'created_at': '2016-07-25T11:24:17Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/EyenukInc'},
#     'updated_at': '2022-10-18T19:14:47Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'e4de7045-68d4-9131-65e3-4bc40d076d25',
#    'properties': {'name': 'HopSkipDrive',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'hopskipdrive',
#      'image_id': 'wk4gbpfj1c7fetmbsy5t',
#      'uuid': 'e4de7045-68d4-9131-65e3-4bc40d076d25',
#      'entity_def_id': 'organization',
#      'value': 'HopSkipDrive'},
#     'linkedin': {'value': 'http://www.linkedin.com/company/hopskipdrive'},
#     'short_description': 'HopSkipDrive is a vehicle for hire company focused on shuttling kids to school.',
#     'facebook': {'value': 'http://www.facebook.com/hopskipdrive'},
#     'created_at': '2014-10-14T09:24:22Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'http://twitter.com/HopSkipDrive'},
#     'updated_at': '2022-09-13T20:56:30Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'c73be3d5-d7d4-e9de-fc51-bb5f702821be',
#    'properties': {'name': 'Camino Financial',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'camino-financial',
#      'image_id': 'nw0bp7ipbziex6k03jmb',
#      'uuid': 'c73be3d5-d7d4-e9de-fc51-bb5f702821be',
#      'entity_def_id': 'organization',
#      'value': 'Camino Financial'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/camino-financial'},
#     'short_description': 'Camino Financial is an online finance company that offers business loans and wealth-building solutions to help small businesses grow.',
#     'facebook': {'value': 'https://www.facebook.com/caminofinancial/info/?tab=page_info'},
#     'created_at': '2015-11-10T04:27:08Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/caminofinancial'},
#     'updated_at': '2022-04-07T19:12:58Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'c13b40dd-1db9-47ea-9f47-351e0d000932',
#    'properties': {'name': 'Morpheus Space',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'morpheus-space',
#      'image_id': 'kpz1ievmz5k6730wn44o',
#      'uuid': 'c13b40dd-1db9-47ea-9f47-351e0d000932',
#      'entity_def_id': 'organization',
#      'value': 'Morpheus Space'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/morpheus-space'},
#     'short_description': 'Morpheus Space is an aerospace company that produces a modular and electric propulsion system for the small satellite industry.',
#     'facebook': {'value': 'https://www.facebook.com/MorpheusSpace'},
#     'created_at': '2019-03-12T15:22:45Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/morpheusspace'},
#     'updated_at': '2022-09-15T16:21:50Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'e9e3e641-a027-4f41-9c64-94b4ab902c15',
#    'properties': {'name': 'AmazeVR',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'amazevr',
#      'image_id': 'gdtt8pelkinjhkzk6oid',
#      'uuid': 'e9e3e641-a027-4f41-9c64-94b4ab902c15',
#      'entity_def_id': 'organization',
#      'value': 'AmazeVR'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/amazevr'},
#     'short_description': 'AmazeVR is a virtual concert platform for VR content creation and mass distribution using proprietary technologies.',
#     'facebook': {'value': 'https://www.facebook.com/AmazeVR'},
#     'created_at': '2018-07-28T04:16:54Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/AmazeVR'},
#     'updated_at': '2022-10-14T14:57:56Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '85e67b89-5b5a-d037-7c0a-487c11cb6e1f',
#    'properties': {'name': 'Honey',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'honey-science',
#      'image_id': 'nju7ndd92elxel1zjvql',
#      'uuid': '85e67b89-5b5a-d037-7c0a-487c11cb6e1f',
#      'entity_def_id': 'organization',
#      'value': 'Honey'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/honey-inc-'},
#     'short_description': 'Honey is a shopping platform that provides access to exclusive savings, deals, rewards, and discovery.',
#     'facebook': {'value': 'http://www.facebook.com/honey'},
#     'created_at': '2013-09-07T06:10:43Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'http://twitter.com/honey'},
#     'updated_at': '2022-03-17T05:42:42Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'eed1402a-ba63-4415-9ec4-eb4707f4b4d2',
#    'properties': {'name': 'Stellar Pizza',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'steller-pizza',
#      'image_id': 'qflhwemcegazji9hyafj',
#      'uuid': 'eed1402a-ba63-4415-9ec4-eb4707f4b4d2',
#      'entity_def_id': 'organization',
#      'value': 'Stellar Pizza'},
#     'short_description': 'A robotic-powered mobile pizza-making restaurant',
#     'created_at': '2021-11-30T02:38:47Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'updated_at': '2022-10-08T04:33:44Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'ae197d56-d7da-8d86-a5a1-288c84b3627c',
#    'properties': {'name': 'UpKeep',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'upkeep-maintenance-management',
#      'image_id': 'v1485204543/qdctfzygbql7yduvx3p5.png',
#      'uuid': 'ae197d56-d7da-8d86-a5a1-288c84b3627c',
#      'entity_def_id': 'organization',
#      'value': 'UpKeep'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/upkeep-maintenance-management/'},
#     'short_description': 'UpKeep is a platform developed for technicians and maintenance workers that provides them with a computerized maintenance management system.',
#     'facebook': {'value': 'https://www.facebook.com/onupkeep'},
#     'created_at': '2015-04-01T07:08:35Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/OnUpKeep'},
#     'updated_at': '2022-07-19T01:48:13Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '7da33e79-db23-601b-6902-ee11cb65a656',
#    'properties': {'name': 'Mahmee',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'mahmee',
#      'image_id': 'qyugwj2fc8qwiaa1tolu',
#      'uuid': '7da33e79-db23-601b-6902-ee11cb65a656',
#      'entity_def_id': 'organization',
#      'value': 'Mahmee'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/mahmee/'},
#     'short_description': 'Mahmee is an integrated care delivery platform for maternal and infant health.',
#     'facebook': {'value': 'https://www.facebook.com/getmahmee'},
#     'created_at': '2016-01-13T05:37:11Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/getmahmee'},
#     'updated_at': '2022-03-12T00:59:27Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '5df7b3c7-d0f4-2ff1-b7ad-74c67706cd2f',
#    'properties': {'name': 'Blavity',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'blavity',
#      'image_id': 'tgtkxxka1bwmq4lak1dj',
#      'uuid': '5df7b3c7-d0f4-2ff1-b7ad-74c67706cd2f',
#      'entity_def_id': 'organization',
#      'value': 'Blavity'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/blavityinc'},
#     'short_description': 'Blavity is home to the network of platforms and brands serving the multifaceted lives of Black millennials and gen-z.',
#     'facebook': {'value': 'https://www.facebook.com/Blavity'},
#     'created_at': '2015-08-12T08:28:39Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/blavity'},
#     'updated_at': '2022-06-13T04:02:30Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '96609ce7-93ae-4850-9844-9af4d58d2095',
#    'properties': {'name': 'Theorycraft Games',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'theorycraft-games',
#      'image_id': 'x08qo8ywoxkzk4szc1ew',
#      'uuid': '96609ce7-93ae-4850-9844-9af4d58d2095',
#      'entity_def_id': 'organization',
#      'value': 'Theorycraft Games'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/theorycraft-games/about/'},
#     'short_description': 'Theorycraft Games operates as an independent game development studio that operates remotely.',
#     'facebook': {'value': 'https://www.facebook.com/theorycraftgames'},
#     'created_at': '2021-03-05T07:06:14Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/theorycraft_inc'},
#     'updated_at': '2022-09-23T19:12:06Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '3fd85e7b-44ee-187c-5168-7c97a2274885',
#    'properties': {'name': 'GoGuardian',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'goguardian',
#      'image_id': 'rs8vakvpnpbwqvsumuap',
#      'uuid': '3fd85e7b-44ee-187c-5168-7c97a2274885',
#      'entity_def_id': 'organization',
#      'value': 'GoGuardian'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/goguardian'},
#     'short_description': 'GoGuardian is an edtech startup that makes subscription software for K-12 schools.',
#     'facebook': {'value': 'https://www.facebook.com/goguardian'},
#     'created_at': '2014-10-16T20:32:50Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'http://twitter.com/goguardian'},
#     'updated_at': '2021-08-12T06:07:31Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '15c25da3-170e-0cba-d214-5ff56bbbc670',
#    'properties': {'name': 'Moving Analytics',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'moving-analytics',
#      'image_id': 'mdlmqib90xlvuefvay29',
#      'uuid': '15c25da3-170e-0cba-d214-5ff56bbbc670',
#      'entity_def_id': 'organization',
#      'value': 'Moving Analytics'},
#     'linkedin': {'value': 'http://www.linkedin.com/company/moving-analytics-inc-'},
#     'short_description': 'Moving Analytics is a telehealth service provider that specializes in cardiovascular prevention programs.',
#     'facebook': {'value': 'http://www.facebook.com/movinganalytics'},
#     'created_at': '2014-03-18T06:50:19Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/movinganalytics'},
#     'updated_at': '2022-07-19T01:17:17Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '3c635fc0-4aaa-c084-0d48-e3cf7942a0b5',
#    'properties': {'name': 'RentSpree',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'rentspree-com',
#      'image_id': 'ra2zvikseql7oxmdpo6q',
#      'uuid': '3c635fc0-4aaa-c084-0d48-e3cf7942a0b5',
#      'entity_def_id': 'organization',
#      'value': 'RentSpree'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/rentspree'},
#     'short_description': 'RentSpree provides software with a universal tenant screening process, renter management, partnership programs, and rental screening API.',
#     'facebook': {'value': 'http://www.facebook.com/rentspree'},
#     'created_at': '2016-06-08T23:07:03Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/rentspree'},
#     'updated_at': '2022-08-29T20:59:34Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '28ce82f3-c1fc-973d-dbee-7fe242773b9e',
#    'properties': {'name': 'VideoAmp',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'videoamp',
#      'image_id': 'v1506108937/lknqjsp0fctycftk31ai.png',
#      'uuid': '28ce82f3-c1fc-973d-dbee-7fe242773b9e',
#      'entity_def_id': 'organization',
#      'value': 'VideoAmp'},
#     'linkedin': {'value': 'http://www.linkedin.com/company/videoamp'},
#     'short_description': 'VideoAmp is a software and data company that provides measurement and optimization tools for the advertising ecosystem.',
#     'facebook': {'value': 'https://www.facebook.com/VideoAmpOfficial/'},
#     'created_at': '2014-08-23T14:41:14Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'http://twitter.com/Video_Amp'},
#     'updated_at': '2022-07-19T02:43:51Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '763f7a66-8416-4262-8f8e-64edf50e0c62',
#    'properties': {'name': 'Spotter',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'spotter-0c62',
#      'image_id': 'kxjxabv0xw1kbo9rhfa7',
#      'uuid': '763f7a66-8416-4262-8f8e-64edf50e0c62',
#      'entity_def_id': 'organization',
#      'value': 'Spotter'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/spotter-inc/'},
#     'short_description': 'Spotter provides a financial solution for independent content creators across digital platforms.',
#     'created_at': '2020-06-23T17:41:03Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'updated_at': '2022-09-05T14:17:55Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'd503fddd-25c2-4010-a211-7496d94c1ecd',
#    'properties': {'name': 'FORME Life',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'forme-life',
#      'image_id': 'w0w4jgmmrwtuongfqj93',
#      'uuid': 'd503fddd-25c2-4010-a211-7496d94c1ecd',
#      'entity_def_id': 'organization',
#      'value': 'FORME Life'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/formelife'},
#     'short_description': 'FORME Life is a modular smart home gym and home fitness system for fitness and strength workouts.',
#     'facebook': {'value': 'https://www.facebook.com/FORMELifeOfficial'},
#     'created_at': '2020-10-20T03:16:50Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'updated_at': '2022-10-03T06:31:38Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'c2f5f388-fd78-407b-a002-e009d6cb10d7',
#    'properties': {'name': 'Laylo',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'laylo',
#      'image_id': 'jptslmqslhieqwvfkc1p',
#      'uuid': 'c2f5f388-fd78-407b-a002-e009d6cb10d7',
#      'entity_def_id': 'organization',
#      'value': 'Laylo'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/darkchart/'},
#     'short_description': 'Laylo helps creators connect with and monetize their super fans through live ticketed digital experiences.',
#     'created_at': '2019-09-13T00:13:58Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/getlaylo'},
#     'updated_at': '2022-08-11T13:06:04Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'fdb11ac2-bff4-b739-6e0f-0d39e5c1a33b',
#    'properties': {'name': 'Papaya',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'papaya-payments',
#      'image_id': 'vfqyw3zeeuvcbe14xigg',
#      'uuid': 'fdb11ac2-bff4-b739-6e0f-0d39e5c1a33b',
#      'entity_def_id': 'organization',
#      'value': 'Papaya'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/papaya-payments/'},
#     'short_description': 'Papaya is a developer of an online mobile application and payments technology designed to simplify bill payment for consumers.',
#     'created_at': '2016-08-26T05:00:10Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/papayapay'},
#     'updated_at': '2022-07-19T00:50:18Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'a1572bc4-2e78-4d89-acdf-44e7aafe4f7c',
#    'properties': {'name': 'Arro',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'arro-4f7c',
#      'image_id': 'liz6jnveaoeijpkxojua',
#      'uuid': 'a1572bc4-2e78-4d89-acdf-44e7aafe4f7c',
#      'entity_def_id': 'organization',
#      'value': 'Arro'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/arrofinance/'},
#     'short_description': 'Arro is a Los Angeles-based fintech company democratizing access to credit.',
#     'created_at': '2022-08-23T23:19:51Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/arrofinance'},
#     'updated_at': '2022-10-12T12:17:38Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '3bc2e117-8e50-459b-8694-24ddb3fa2adb',
#    'properties': {'name': 'Path',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'path-2adb',
#      'image_id': 'kok0fvcwifdwkzqnpn0m',
#      'uuid': '3bc2e117-8e50-459b-8694-24ddb3fa2adb',
#      'entity_def_id': 'organization',
#      'value': 'Path'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/pathccm'},
#     'short_description': 'Path makes it easy to find a world class mental health provider that’s covered by your insurance.',
#     'facebook': {'value': 'https://www.facebook.com/PathCCM/'},
#     'created_at': '2019-10-25T04:32:13Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/pathccm'},
#     'updated_at': '2022-07-19T01:32:39Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'a654b8cc-c46f-4ac2-8de2-830de8a39cfd',
#    'properties': {'name': 'Thrilling',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'thrilling',
#      'image_id': 'erwm9e84sponxwdrj3gz',
#      'uuid': 'a654b8cc-c46f-4ac2-8de2-830de8a39cfd',
#      'entity_def_id': 'organization',
#      'value': 'Thrilling'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/thrilling'},
#     'short_description': 'Thrilling is an online marketplace that offers curated vintage and secondhand items.',
#     'facebook': {'value': 'https://www.facebook.com/ShopThrilling'},
#     'created_at': '2019-04-30T20:40:56Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/shopthrilling'},
#     'updated_at': '2022-07-19T01:35:55Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'fc6ecaaa-2b2d-4de7-a015-85a84e3719d0',
#    'properties': {'name': 'Cloud9',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'cloud9',
#      'image_id': 'ohovqvmjwxbkrmsjp74u',
#      'uuid': 'fc6ecaaa-2b2d-4de7-a015-85a84e3719d0',
#      'entity_def_id': 'organization',
#      'value': 'Cloud9'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/cloud9-esports/'},
#     'short_description': 'Cloud9 is a professional multi-game esports organization that is based in the Los Angeles, California area.',
#     'facebook': {'value': 'https://www.facebook.com/cloud9'},
#     'created_at': '2015-03-09T12:59:20Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://www.twitter.com/Cloud9'},
#     'updated_at': '2022-06-13T08:11:56Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '11350cd0-6ae2-7139-45c0-eed3ccc3a743',
#    'properties': {'name': 'Thrive Market',
#     'facet_ids': ['investor', 'company', 'rank'],
#     'identifier': {'permalink': 'thrive-market',
#      'image_id': 'tsif3hvfcstk76qqwpdn',
#      'uuid': '11350cd0-6ae2-7139-45c0-eed3ccc3a743',
#      'entity_def_id': 'organization',
#      'value': 'Thrive Market'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/thrivemarket'},
#     'short_description': 'Thrive Market is a membership-based online company that offers natural and organic food products.',
#     'facebook': {'value': 'https://www.facebook.com/thrivemarket'},
#     'created_at': '2014-11-05T16:05:07Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/ThriveMarket'},
#     'updated_at': '2021-06-04T14:26:20Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'e2ff460c-bc7f-d14e-7b73-689370f9ce2d',
#    'properties': {'name': 'Heal',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'heal',
#      'image_id': 'v1504798141/vvxfjqwi3sxh3p2gg5g1.png',
#      'uuid': 'e2ff460c-bc7f-d14e-7b73-689370f9ce2d',
#      'entity_def_id': 'organization',
#      'value': 'Heal'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/healapp'},
#     'short_description': 'Heal is an in-home primary care practice that offers modern doctor house calls, one-touch telemedicine and remote monitoring for seniors.',
# ...
#     'updated_at': '2021-10-16T06:32:25Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '032e620c-b629-4ff8-b64e-91c330682657',
#    'properties': {'name': 'Crooked Media',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'crooked-media',
#      'image_id': 'q1qdloh0ozhgtl0i5yva',
#      'uuid': '032e620c-b629-4ff8-b64e-91c330682657',
#      'entity_def_id': 'organization',
#      'value': 'Crooked Media'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/crooked-media/'},
#     'short_description': 'Crooked Media is a place for political news, analysis, and to figure out how you can get involved.',
#     'facebook': {'value': 'https://www.facebook.com/TheCrookedMedia/'},
#     'created_at': '2018-11-21T19:47:08Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/crookedmedia'},
#     'updated_at': '2018-11-21T19:47:08Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '7c28a056-54a1-6e23-0b8e-3418a3834f1e',
#    'properties': {'name': 'Sinemia',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'sinemia',
#      'image_id': 'quf3jllhfcgjjx9tfywf',
#      'uuid': '7c28a056-54a1-6e23-0b8e-3418a3834f1e',
#      'entity_def_id': 'organization',
#      'value': 'Sinemia'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/brandia-bili%C5%9Fim-a-%C5%9F-'},
#     'short_description': 'Sinemia is a social platform for moviegoers and a monthly subscription-based service.',
#     'facebook': {'value': 'https://www.facebook.com/sinemiaApp'},
#     'created_at': '2015-06-01T01:24:28Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/SinemiaApp'},
#     'updated_at': '2022-05-27T07:43:43Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'ee6fa50b-5b4b-d6b5-9da9-26f63314bdda',
#    'properties': {'name': 'Broadway Financial',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'broadway-financial',
#      'image_id': 'v1403004721/odoj9wq4ueg8rpvdexny.png',
#      'uuid': 'ee6fa50b-5b4b-d6b5-9da9-26f63314bdda',
#      'entity_def_id': 'organization',
#      'value': 'Broadway Financial'},
#     'short_description': 'Broadway Financial is a Los Angeles-based savings and loan holding company.',
#     'created_at': '2014-06-17T11:34:13Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'updated_at': '2021-04-27T21:49:03Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': '5e19d904-7da1-42e2-8a78-4655f528143a',
#    'properties': {'name': 'Doctorpedia',
#     'facet_ids': ['rank', 'company'],
#     'identifier': {'permalink': 'doctorpedia',
#      'image_id': 'b2a59f245b25773a0e42',
#      'uuid': '5e19d904-7da1-42e2-8a78-4655f528143a',
#      'entity_def_id': 'organization',
#      'value': 'Doctorpedia'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/doctorpediaofficial/'},
#     'short_description': "Doctorpedia's mission is to help a passionate community of doctors reach, educate, and empower people with evidence-based health videos.",
#     'facebook': {'value': 'https://www.facebook.com/doctorpediateam/'},
#     'created_at': '2020-01-31T23:50:56Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'updated_at': '2022-08-04T09:03:15Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'ba19738f-47e3-4611-a3d5-9c2b32f58118',
#    'properties': {'name': 'Marble',
#     'facet_ids': ['rank', 'company'],
#     'identifier': {'permalink': 'marble-8118',
#      'image_id': 'uhfnjj3cfsgq0sefaqhr',
#      'uuid': 'ba19738f-47e3-4611-a3d5-9c2b32f58118',
#      'entity_def_id': 'organization',
#      'value': 'Marble'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/marblear'},
#     'short_description': 'Marble is the first platform that brings the Metaverse and NFTs to the real world.',
#     'facebook': {'value': 'https://www.facebook.com/marblearlive/'},
#     'created_at': '2019-12-09T08:11:11Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/marblearlive'},
#     'updated_at': '2022-03-24T05:39:19Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'c08cc867-c5de-0b28-12ee-d67017028d96',
#    'properties': {'name': 'Trendy Butler',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'trendy-butler',
#      'image_id': 'hp7x9wdbdecnmmozn5ah',
#      'uuid': 'c08cc867-c5de-0b28-12ee-d67017028d96',
#      'entity_def_id': 'organization',
#      'value': 'Trendy Butler'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/3840414'},
#     'short_description': "Trendy Butler is a diverse men's apparel subscription service that gives members a box of the newest, most fashionable clothing.",
#     'facebook': {'value': 'https://www.facebook.com/TrendyButler'},
#     'created_at': '2015-10-06T01:09:22Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/trendybutler'},
#     'updated_at': '2019-06-24T21:59:39Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'c3382b4e-c493-451f-b2d2-c66fd68d1acb',
#    'properties': {'name': 'Wonder',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'wonder-1acb',
#      'image_id': 'vzfxhcslwwvqiwmnzpvo',
#      'uuid': 'c3382b4e-c493-451f-b2d2-c66fd68d1acb',
#      'entity_def_id': 'organization',
#      'value': 'Wonder'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/joinwonder'},
#     'short_description': 'Wonder is a gaming company that develops an all-in-one gaming platform for Android mobile devices.',
#     'facebook': {'value': 'https://www.facebook.com/JoinWONDER'},
#     'created_at': '2022-07-27T17:18:14Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/joinwonder'},
#     'updated_at': '2022-07-29T12:02:25Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'abffe638-efaf-9392-1aa8-7dcef2af7c40',
#    'properties': {'name': 'Firefly Games',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'firefly-games',
#      'image_id': 'v1424234970/vh1q4zyy9dcwx1gxzmba.png',
#      'uuid': 'abffe638-efaf-9392-1aa8-7dcef2af7c40',
#      'entity_def_id': 'organization',
#      'value': 'Firefly Games'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/firefly-games-inc-?trk=ppro_cprof'},
#     'short_description': 'Firefly Games community and enjoy free to play games like Rising Heroes and more.',
#     'facebook': {'value': 'https://www.facebook.com/pages/Rising-Heroes/648748728587900'},
#     'created_at': '2015-02-18T04:40:25Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://www.twitter.com/fireflygames'},
#     'updated_at': '2022-07-19T00:48:59Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'f7b8e2e3-4ce5-4cbe-9a34-885ea7be64fd',
#    'properties': {'name': 'Cinelytic',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'cinelytic',
#      'image_id': 'cilz1hsw5qwlcg8ozzij',
#      'uuid': 'f7b8e2e3-4ce5-4cbe-9a34-885ea7be64fd',
#      'entity_def_id': 'organization',
#      'value': 'Cinelytic'},
#     'linkedin': {'value': 'https://www.linkedin.com/company/cinelytic.com/'},
#     'short_description': 'Cinelytic empowers global entertainment industry through cutting edge tools and technology.',
#     'facebook': {'value': 'https://www.facebook.com/cinelytic/'},
#     'created_at': '2018-09-06T03:52:58Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'https://twitter.com/cinelytic'},
#     'updated_at': '2020-05-15T15:07:36Z',
#     'entity_def_id': 'organization'}},
#   {'uuid': 'f1dff14a-7932-0de5-c6da-c61cae2b0a5b',
#    'properties': {'name': 'Nelson-Miller',
#     'facet_ids': ['company', 'rank'],
#     'identifier': {'permalink': 'nelson-miller',
#      'image_id': 'v1397194379/fbcf39af0e56b9021c3be559f966e794.jpg',
#      'uuid': 'f1dff14a-7932-0de5-c6da-c61cae2b0a5b',
#      'entity_def_id': 'organization',
#      'value': 'Nelson-Miller'},
#     'linkedin': {'value': 'http://www.linkedin.com/company/nelson-miller-inc-'},
#     'short_description': 'Nelson-Miller designs, manufactures and sources customized membrane switches, nameplates, touch screens, keypads.',
#     'facebook': {'value': 'http://www.facebook.com/NelsonMillerInc'},
#     'created_at': '2012-05-02T18:51:07Z',
#     'location_identifiers': [{'permalink': 'los-angeles-california',
#       'uuid': '4ce61f42-f6c4-e7ec-798d-44813b58856b',
#       'location_type': 'city',
#       'entity_def_id': 'location',
#       'value': 'Los Angeles'},
#      {'permalink': 'california-united-states',
#       'uuid': 'eb879a83-c91a-121e-0bb8-829782dbcf04',
#       'location_type': 'region',
#       'entity_def_id': 'location',
#       'value': 'California'},
#      {'permalink': 'united-states',
#       'uuid': 'f110fca2-1055-99f6-996d-011c198b3928',
#       'location_type': 'country',
#       'entity_def_id': 'location',
#       'value': 'United States'},
#      {'permalink': 'north-america',
#       'uuid': 'b25caef9-a1b8-3a5d-6232-93b2dfb6a1d1',
#       'location_type': 'continent',
#       'entity_def_id': 'location',
#       'value': 'North America'}],
#     'twitter': {'value': 'http://twitter.com/nelsonmillerinc'},
#     'updated_at': '2019-06-24T22:16:35Z',
#     'entity_def_id': 'organization'}}]}

# %%
raw=pd.DataFrame()
normalized_raw = json_normalize(result['entities'])
raw = raw.append(normalized_raw,ignore_index=True)

# %%
raw.columns
# Out:
# Index(['uuid', 'properties.name', 'properties.facet_ids',
#        'properties.identifier.permalink', 'properties.identifier.image_id',
#        'properties.identifier.uuid', 'properties.identifier.entity_def_id',
#        'properties.identifier.value', 'properties.linkedin.value',
#        'properties.short_description', 'properties.created_at',
#        'properties.location_identifiers', 'properties.twitter.value',
#        'properties.updated_at', 'properties.entity_def_id',
#        'properties.facebook.value'],
#       dtype='object')

# %%
raw
# Out:
#                                      uuid properties.name  \
# 0    e24eb956-a671-46fe-a04b-d461684f016b     Blockdaemon
# 1    58a49f48-f049-1150-d215-51ee302ae0dd      Riot Games
# 2    e4f41fbf-eea3-2db9-0c69-cd16f5cfc0e9            Hulu
# 3    1e349e9f-1206-6a22-434b-9ca4281a360d          Bambee
# 4    0f3fd8ce-9fe3-d6bd-d243-ffdf2fcfb012     StartEngine
# ..                                    ...             ...
# 995  c08cc867-c5de-0b28-12ee-d67017028d96   Trendy Butler
# 996  c3382b4e-c493-451f-b2d2-c66fd68d1acb          Wonder
# 997  abffe638-efaf-9392-1aa8-7dcef2af7c40   Firefly Games
# 998  f7b8e2e3-4ce5-4cbe-9a34-885ea7be64fd       Cinelytic
# 999  f1dff14a-7932-0de5-c6da-c61cae2b0a5b   Nelson-Miller
#
#           properties.facet_ids properties.identifier.permalink  \
# 0    [investor, company, rank]                     blockdaemon
# 1    [investor, company, rank]                      riot-games
# 2              [company, rank]                            hulu
# 3              [company, rank]                          bambee
# 4    [investor, company, rank]                    start-engine
# ..                         ...                             ...
# 995            [company, rank]                   trendy-butler
# 996            [company, rank]                     wonder-1acb
# 997            [company, rank]                   firefly-games
# 998            [company, rank]                       cinelytic
# 999            [company, rank]                   nelson-miller
#
#                        properties.identifier.image_id  \
# 0                                loofgtnytw5te0ssqlyb
# 1                                aokeyvfmozfn00cuy1xk
# 2                                bk8cux6dapq8qjzylfaj
# 3                                pctmar5rcej0bdkovnvd
# 4                                oxevxb0jcpmjqqrwfurc
# ..                                                ...
# 995                              hp7x9wdbdecnmmozn5ah
# 996                              vzfxhcslwwvqiwmnzpvo
# 997              v1424234970/vh1q4zyy9dcwx1gxzmba.png
# 998                              cilz1hsw5qwlcg8ozzij
# 999  v1397194379/fbcf39af0e56b9021c3be559f966e794.jpg
#
#                properties.identifier.uuid properties.identifier.entity_def_id  \
# 0    e24eb956-a671-46fe-a04b-d461684f016b                        organization
# 1    58a49f48-f049-1150-d215-51ee302ae0dd                        organization
# 2    e4f41fbf-eea3-2db9-0c69-cd16f5cfc0e9                        organization
# 3    1e349e9f-1206-6a22-434b-9ca4281a360d                        organization
# 4    0f3fd8ce-9fe3-d6bd-d243-ffdf2fcfb012                        organization
# ..                                    ...                                 ...
# 995  c08cc867-c5de-0b28-12ee-d67017028d96                        organization
# 996  c3382b4e-c493-451f-b2d2-c66fd68d1acb                        organization
# 997  abffe638-efaf-9392-1aa8-7dcef2af7c40                        organization
# 998  f7b8e2e3-4ce5-4cbe-9a34-885ea7be64fd                        organization
# 999  f1dff14a-7932-0de5-c6da-c61cae2b0a5b                        organization
#
#     properties.identifier.value  \
# 0                   Blockdaemon
# 1                    Riot Games
# 2                          Hulu
# 3                        Bambee
# 4                   StartEngine
# ..                          ...
# 995               Trendy Butler
# 996                      Wonder
# 997               Firefly Games
# 998                   Cinelytic
# 999               Nelson-Miller
#
#                              properties.linkedin.value  \
# 0         https://www.linkedin.com/company/blockdaemon
# 1           http://www.linkedin.com/company/riot-games
# 2                https://www.linkedin.com/company/hulu
# 3             https://www.linkedin.com/company/bambee/
# 4         https://www.linkedin.com/company/startengine
# ..                                                 ...
# 995           https://www.linkedin.com/company/3840414
# 996        https://www.linkedin.com/company/joinwonder
# 997  https://www.linkedin.com/company/firefly-games...
# 998    https://www.linkedin.com/company/cinelytic.com/
# 999  http://www.linkedin.com/company/nelson-miller-...
#
#                           properties.short_description properties.created_at  \
# 0    Blockdaemon is a blockchain deployment facilit...  2018-01-30T06:43:59Z
# 1    Riot Games is a global company that develops o...  2008-07-12T01:53:08Z
# 2    Hulu is an online video service that offers a ...  2007-08-29T23:07:06Z
# 3    Bambee is a platform offering an affordable so...  2016-08-31T01:35:49Z
# 4    StartEngine is an equity crowdfunding platform...  2012-01-17T09:20:52Z
# ..                                                 ...                   ...
# 995  Trendy Butler is a diverse men's apparel subsc...  2015-10-06T01:09:22Z
# 996  Wonder is a gaming company that develops an al...  2022-07-27T17:18:14Z
# 997  Firefly Games community and enjoy free to play...  2015-02-18T04:40:25Z
# 998  Cinelytic empowers global entertainment indust...  2018-09-06T03:52:58Z
# 999  Nelson-Miller designs, manufactures and source...  2012-05-02T18:51:07Z
#
#                        properties.location_identifiers  \
# 0    [{'permalink': 'los-angeles-california', 'uuid...
# 1    [{'permalink': 'los-angeles-california', 'uuid...
# 2    [{'permalink': 'los-angeles-california', 'uuid...
# 3    [{'permalink': 'los-angeles-california', 'uuid...
# 4    [{'permalink': 'los-angeles-california', 'uuid...
# ..                                                 ...
# 995  [{'permalink': 'los-angeles-california', 'uuid...
# 996  [{'permalink': 'los-angeles-california', 'uuid...
# 997  [{'permalink': 'los-angeles-california', 'uuid...
# 998  [{'permalink': 'los-angeles-california', 'uuid...
# 999  [{'permalink': 'los-angeles-california', 'uuid...
#
#                  properties.twitter.value properties.updated_at  \
# 0        https://twitter.com/_blockdaemon  2022-03-09T12:38:37Z
# 1            http://twitter.com/riotgames  2019-01-02T16:42:59Z
# 2            https://www.twitter.com/hulu  2019-03-25T20:42:50Z
# 3            https://twitter.com/BambeeHQ  2022-08-17T17:07:50Z
# 4       https://twitter.com/startenginela  2022-02-06T01:07:45Z
# ..                                    ...                   ...
# 995      https://twitter.com/trendybutler  2019-06-24T21:59:39Z
# 996        https://twitter.com/joinwonder  2022-07-29T12:02:25Z
# 997  https://www.twitter.com/fireflygames  2022-07-19T00:48:59Z
# 998         https://twitter.com/cinelytic  2020-05-15T15:07:36Z
# 999    http://twitter.com/nelsonmillerinc  2019-06-24T22:16:35Z
#
#     properties.entity_def_id  \
# 0               organization
# 1               organization
# 2               organization
# 3               organization
# 4               organization
# ..                       ...
# 995             organization
# 996             organization
# 997             organization
# 998             organization
# 999             organization
#
#                              properties.facebook.value
# 0                                                  NaN
# 1             http://www.facebook.com/RiotGamesTurkiye
# 2                       https://www.facebook.com/hulu/
# 3                   https://www.facebook.com/bambeeHQ/
# 4              https://www.facebook.com/StartEngineLA/
# ..                                                 ...
# 995              https://www.facebook.com/TrendyButler
# 996                https://www.facebook.com/JoinWONDER
# 997  https://www.facebook.com/pages/Rising-Heroes/6...
# 998                https://www.facebook.com/cinelytic/
# 999            http://www.facebook.com/NelsonMillerInc
#
# [1000 rows x 16 columns]
