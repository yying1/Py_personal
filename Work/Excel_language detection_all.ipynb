# %%
from langdetect import detect
from langdetect import detect_langs
import pandas as pd
import re

# %%
## this is an example 
s1 = "本篇博客主要介绍两款语言探测工具，用于区分文本到底是什么语言，"
s2 = 'We are pleased to introduce today a new technology – Record Matching –that automatically finds relevant historical records for every family tree on MyHerit'
s3 = "Javigator：Java代码导读及分析管理工具的设计"

print(detect(s1))
print(detect(s2))
print(detect(s3))     # detect()输出探测出的语言类型
print(detect_langs(s3))

# %%
df = pd.read_excel(r"C:\Users\yingyy\Desktop\ES2UK_Des_SaarTest_Result.xlsx")

# %%
for index, row in df.iterrows(): 
    for col in df.columns.tolist():
        if str(col).lower != 'asin':
            try:
                row[col].value = re.sub('^[=/-]+', '', row[col].value)
            except:
                pass

# %%
df.head()
# Out:
#          asin                     rtip_product_description.value  \
# 0  B0881P4LJD  En TEX ponemos a tu disposicin una amplia vari...
# 1  B0881PL7F4  En TEX ponemos a tu disposicin una amplia vari...
# 2  B087XBM6FM  En TEX ponemos a tu disposicin una amplia vari...
# 3  B087XBKJ1B  En TEX ponemos a tu disposicin una amplia vari...
# 4  B087X9N3WG  En TEX ponemos a tu disposicin una amplia vari...
#
#                                                 Saar            original_type  \
# 0  At TEX we offer you a wide variety of products...  [es:0.9999962454684916]
# 1  At TEX we offer you a wide variety of products...  [es:0.9999962390754396]
# 2  At TEX we offer you a wide variety of products...  [es:0.9999953798142293]
# 3  At TEX we offer you a wide variety of products...  [es:0.9999965172526148]
# 4  At TEX we offer you a wide variety of products...  [es:0.9999971309173212]
#
#                  saar_type rtip_product_description.value_result Saar_result  \
# 0  [en:0.9999952388389005]
# 1  [en:0.9999965654006424]
# 2  [en:0.9999972946591766]
# 3  [en:0.9999983565707168]
# 4  [en:0.9999981493720607]
#
#   original_type_result saar_type_result
# 0
# 1
# 2
# 3
# 4

# %%
for col in df.columns.tolist():
    if col != 'asin':
        df[col+'_result'] = ''

# %%
for index, row in df.iterrows(): 
    for col in df.columns.tolist():
        if 'asin' not in str(col) and '_result' not in str(col):
            try:
                print(col)
                if row[col].strip() != '':
                    print (detect_langs(row[col].strip()))
                    row[col+'_result'] = detect_langs(row[col].strip())
            except:
                row[col+'_result'] = 'Error'
# Out:
# rtip_product_description.value
# [es:0.9999949880274224]
# Saar
# [en:0.9999971072079399]
# original_type
# [fr:0.9999920236958381]
# saar_type
# [nl:0.9999933498316416]
# rtip_product_description.value
# [es:0.9999965244666744]
# Saar
# [en:0.9999982704460553]
# original_type
# [fr:0.9999926460918287]
# saar_type
# [nl:0.9999953087605712]
# rtip_product_description.value
# [es:0.9999967309576699]
# Saar
# [en:0.9999970730433193]
# original_type
# [fr:0.9999926564324302]
# saar_type
# [nl:0.9999941055702853]
# rtip_product_description.value
# [es:0.9999952258902551]
# Saar
# [en:0.9999960193252088]
# original_type
# [fr:0.9999920727334775]
# saar_type
# [nl:0.9999948064643892]
# rtip_product_description.value
# [es:0.9999951019417767]
# Saar
# [en:0.9999983547423938]
# original_type
# [fr:0.9999928521437784]
# saar_type
# [nl:0.999994774199966]
# rtip_product_description.value
# [es:0.9999966700227595]
# Saar
# [en:0.9999958354817224]
# original_type
# [fr:0.9999928294657021]
# saar_type
# [nl:0.9999949543379197]
# rtip_product_description.value
# [es:0.9999941586975021]
# Saar
# [en:0.9999965315936775]
# original_type
# [fr:0.9999921194105827]
# saar_type
# [nl:0.9999915977049112]
# rtip_product_description.value
# [es:0.9999960034383535]
# Saar
# [en:0.9999965037309765]
# original_type
# [fr:0.9999915851838546]
# saar_type
# [nl:0.9999927121736677]
# rtip_product_description.value
# [es:0.9999945447647509]
# Saar
# [en:0.9999977551756689]
# original_type
# [fr:0.9999912956802149]
# saar_type
# [nl:0.9999940509659744]

# %%
df.to_excel(r"C:\Users\yingyy\Desktop\ES2UK_Des_SaarTest_Result.xlsx",encoding="utf-8",index = False)
