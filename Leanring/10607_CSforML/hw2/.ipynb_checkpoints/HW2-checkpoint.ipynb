# %% [markdown]
# ### Programming
# #### 3.Dynamic Programming with Markov Chains

# %%
def calc_p_xt_from_p_xt_minus1(p_xt_minus1, p_xt_given_xt_minus1):
    """
    You have been given P(X_{t-1}) for some arbitrary t > 2.
    Compute P(X_t).

    You have also been given P(X_t | X_{t-1}).

    Input:
    p_xt_minus1: NumPy ndarray shape (3,) where p_xt_minus1[i]
        represents P(X_{t-1} = i)
    p_xt_given_xt_minus1: NumPy ndarray shape (3,3) where 
        p_xt_given_xt_minus1[i,j] represents P(X_t = j | X_{t-1} = i)

    Return:
    p_xt: NumPy ndarray shape (3,) where p_xt[i] represents
        P(X_t = i)
    """
    # Code to make sure the input has the correct size
    assert p_xt_minus1.shape == (3,)
    assert p_xt_given_xt_minus1.shape == (3,3)

    ### BEGIN YOUR CODE ###

    p_xt = np.dot(p_xt_minus1,p_xt_given_xt_minus1)


    ### END YOUR CODE ###

    # Code to make sure the output has the correct shape
    assert p_xt.shape == (3,)
    return p_xt

# %%
def calc_p_xt(t, p_x1, p_xt_given_xt_minus1):
    """
    Compute P(X_t) for any t >= 1.
    Hint: make use of calc_p_xt_from_p_xt_minus1

    You been given P(X_1) and P(X_t | X_{t-1}).

    Input:
    t: Integer greater than or equal to 1
    p_x1: NumPy ndarray shape (3,) where p_x1[i] represents
        P(X_1 = i)
    p_xt_given_xt_minus1: NumPy ndarray shape (3,3) where 
        p_xt_given_xt_minus1[i,j] represents P(X_t = j | X_{t-1} = i)

    Return:
    p_xt: NumPy ndarray shape (3,) where p_xt[i] represents
        P(X_t = i)
    """
    # Code to make sure the input has the correct size
    assert p_x1.shape == (3,)
    assert p_xt_given_xt_minus1.shape == (3,3)

    ### BEGIN YOUR CODE ###

    if t == 1:
        return p_x1
    else:
        p_xt =  calc_p_xt_from_p_xt_minus1(calc_p_xt(t-1,p_x1, p_xt_given_xt_minus1),p_xt_given_xt_minus1)

    ### END YOUR CODE ###

    # Code to make sure the output has the correct shape
    assert p_xt.shape == (3,)
    return p_xt

# %%
p_x1 = np.array([0.1, 0.3, 0.6])
p_xt_given_xt_minus1 = np.array([
    [0.3, 0.5, 0.2],
    [0.37, 0.33, 0.3],
    [0.3, 0.5, 0.2]])


# P(X_2)
result_a = calc_p_xt_from_p_xt_minus1(p_x1, p_xt_given_xt_minus1)
print('P(X_2):')
print('Using calc_p_xt_from_p_xt_minus1:', result_a)

result_b = calc_p_xt(2, p_x1, p_xt_given_xt_minus1)
print('Using calc_p_xt:', result_b)
print()

# P(X_3)
result = calc_p_xt(3, p_x1, p_xt_given_xt_minus1)
print('P(X_3):', result)

# P(X_5)
result = calc_p_xt(5, p_x1, p_xt_given_xt_minus1)
print('P(X_5):', result)

# P(X_100)
result = calc_p_xt(100, p_x1, p_xt_given_xt_minus1)
print('P(X_100):', result)

# P(X_900)
result = calc_p_xt(900, p_x1, p_xt_given_xt_minus1)
print('P(X_900):', result)

# %% [markdown]
# ### Programming
# #### 2.Perceptron

# %%
import numpy as np

# %%
train_separable = np.array([[2.7810836,2.550537003,-1],
    [1.465489372,2.362125076,-1],
    [3.396561688,4.400293529,-1],
    [1.38807019,1.850220317,-1],
    [3.06407232,3.005305973,-1],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]])
train_nonseparable = np.array([[2.7810836,2.550537003,-1],
    [1.465489372,2.362125076,-1],
    [3.396561688,4.400293529,1],
    [1.38807019,1.850220317,-1],
    [3.06407232,3.005305973,-1],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,-1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]])
test = np.array([[1.927628496,7.200103829,-1],
    [9.182983992,5.290012983,1]])
n_epoch = 100

# %%
def predict(x, theta):
    """
    Predict y_hat in {-1,1} for a give input x and parameters theta

    Input:
    x: Numpy ndarray shape (2,)
    theta: NumPy ndarray shape (3,), where theta[0] is the bias term
        and theta[1:]

    Return:
    y_hat: -1 or 1
    """
    # Code to make sure the input has the correct size
    assert x.shape == (2,)
    assert theta.shape == (3,)
    # Do not edit any code in this function outside the edit region
    ### BEGIN YOUR CODE ###
    
    if (np.dot(np.transpose(theta)[1:], x) + np.transpose(theta)[0]) == 0:
        y_hat = 0
    elif (np.dot(np.transpose(theta)[1:], x) + np.transpose(theta)[0]) > 0:
        y_hat = 1
    elif (np.dot(np.transpose(theta)[1:], x) + np.transpose(theta)[0]) < 0:
        y_hat = -1
#     print("Predict: ",y_hat)
#     print(x)
#     print(theta)
#     print(np.dot(np.transpose(theta)[1:], x) + np.transpose(theta)[1])
    ### END YOUR CODE ###
    
    return y_hat

# %%
# Run perceptron algorithm
def train(train_x, train_y, n_epoch):
    theta = np.zeros(train_x.shape[1]+1)

    # Train for a fixed number of epochs regardless of convergence
    for epoch in range(n_epoch):
        num_error = 0.0
        for i in range(train_x.shape[0]):
            x = train_x[i,:]
            y_hat = predict(x, theta)

            if train_y[i] != y_hat:
                num_error += 1

            # Update the bias term "theta[0]" and the feature-specific weights "theta[1:]" in the code block below
            ### BEGIN YOUR CODE ###
                if  train_y[i] == 1:
                    theta[0] = theta[0]+1
                    theta[1:] = theta[1:] + x
                elif train_y[i] == -1:
                    theta[0] = theta[0]-1
                    theta[1:] = theta[1:] - x
#                 print("actual y:",train_y[i])
#                 print(theta)
            ### END YOUR CODE ###
        
        print('epoch={}, errors={}'.format(epoch, num_error))
    return theta

# %%
train_separable_x = train_separable[:,:-1]
train_separable_y = train_separable[:,-1]
    
# split non-separable train data into features and predictions
train_nonseparable_x = train_nonseparable[:,:-1]
train_nonseparable_y = train_nonseparable[:,-1]

# split test data into features and predictions
test_x = test[:,:-1]
test_y = test[:,-1]

# train theta using training data
print('Train: separable')
theta = train(train_separable_x, train_separable_y, n_epoch)

# make predictions on test data and compare with groundtruth
print('Test')
for i in range(test.shape[0]):
    x = test_x[i,:]
    prediction = predict(x, theta)
    print("Expected={}, Predicted={}".format(test_y[i], prediction))
print()

# train theta using non-separable training data
print('Train: nonseparable')
theta = train(train_nonseparable_x, train_nonseparable_y, n_epoch)

# make predictions on test data and compare with groundtruth
print('Test')
for i in range(test.shape[0]):
    x = test_x[i,:]
    y_hat = predict(x, theta)
    print("y={}, y_hat={}".format(test_y[i], y_hat))
# Out:
# Train: separable
# epoch=0, errors=2.0
# epoch=1, errors=1.0
# epoch=2, errors=0.0
# epoch=3, errors=0.0
# epoch=4, errors=0.0
# epoch=5, errors=0.0
# epoch=6, errors=0.0
# epoch=7, errors=0.0
# epoch=8, errors=0.0
# epoch=9, errors=0.0
# epoch=10, errors=0.0
# epoch=11, errors=0.0
# epoch=12, errors=0.0
# epoch=13, errors=0.0
# epoch=14, errors=0.0
# epoch=15, errors=0.0
# epoch=16, errors=0.0
# epoch=17, errors=0.0
# epoch=18, errors=0.0
# epoch=19, errors=0.0
# epoch=20, errors=0.0
# epoch=21, errors=0.0
# epoch=22, errors=0.0
# epoch=23, errors=0.0
# epoch=24, errors=0.0
# epoch=25, errors=0.0
# epoch=26, errors=0.0
# epoch=27, errors=0.0
# epoch=28, errors=0.0
# epoch=29, errors=0.0
# epoch=30, errors=0.0
# epoch=31, errors=0.0
# epoch=32, errors=0.0
# epoch=33, errors=0.0
# epoch=34, errors=0.0
# epoch=35, errors=0.0
# epoch=36, errors=0.0
# epoch=37, errors=0.0
# epoch=38, errors=0.0
# epoch=39, errors=0.0
# epoch=40, errors=0.0
# epoch=41, errors=0.0
# epoch=42, errors=0.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
train_separable_p = train_separable[train_separable[:,2]==1]
train_separable_n = train_separable[train_separable[:,2]==-1]
test_p = test[test[:,2]==1]
test_n = test[test[:,2]==-1]

# %%
theta = train(train_separable_x, train_separable_y, n_epoch)
theta
# Out:
# epoch=0, errors=2.0
# epoch=1, errors=1.0
# epoch=2, errors=0.0
# epoch=3, errors=0.0
# epoch=4, errors=0.0
# epoch=5, errors=0.0
# epoch=6, errors=0.0
# epoch=7, errors=0.0
# epoch=8, errors=0.0
# epoch=9, errors=0.0
# epoch=10, errors=0.0
# epoch=11, errors=0.0
# epoch=12, errors=0.0
# epoch=13, errors=0.0
# epoch=14, errors=0.0
# epoch=15, errors=0.0
# epoch=16, errors=0.0
# epoch=17, errors=0.0
# epoch=18, errors=0.0
# epoch=19, errors=0.0
# epoch=20, errors=0.0
# epoch=21, errors=0.0
# epoch=22, errors=0.0
# epoch=23, errors=0.0
# epoch=24, errors=0.0
# epoch=25, errors=0.0
# epoch=26, errors=0.0
# epoch=27, errors=0.0
# epoch=28, errors=0.0
# epoch=29, errors=0.0
# epoch=30, errors=0.0
# epoch=31, errors=0.0
# epoch=32, errors=0.0
# epoch=33, errors=0.0
# epoch=34, errors=0.0
# epoch=35, errors=0.0
# epoch=36, errors=0.0
# epoch=37, errors=0.0
# epoch=38, errors=0.0
# epoch=39, errors=0.0
# epoch=40, errors=0.0
# epoch=41, errors=0.0
# epoch=42, errors=0.0
# ...

# %%
x1 = np.arange(0,12) 
x2 = (-theta[1]* x1 - theta[0])/ theta[2]

# %%
print(x1,x2)

# %%
plt.plot(train_separable_p[:,0], train_separable_p[:,1],'ob',label="train_separable y = 1")
plt.plot(train_separable_n[:,0], train_separable_n[:,1],'or',label="train_separable y = -1")
plt.plot(test_p[:,0], test_p[:,1],'og',label="test y = 1")
plt.plot(test_n[:,0], test_n[:,1],'oy',label="test y = -1")
plt.plot(x1,x2,label="Decision Boundry")
plt.ylim(-1, 10)
plt.xlim(0,12)
plt.legend(loc="upper center")
plt.savefig('2_3.png')
plt.show()

# %%
train_nonseparable_p = train_nonseparable[train_nonseparable[:,2]==1]
train_nonseparable_n = train_nonseparable[train_nonseparable[:,2]==-1]
test_p = test[test[:,2]==1]
test_n = test[test[:,2]==-1]

# %%
theta = train(train_nonseparable_x, train_nonseparable_y, n_epoch)
theta
# Out:
# epoch=0, errors=6.0
# epoch=1, errors=7.0
# epoch=2, errors=5.0
# epoch=3, errors=5.0
# epoch=4, errors=4.0
# epoch=5, errors=4.0
# epoch=6, errors=5.0
# epoch=7, errors=5.0
# epoch=8, errors=4.0
# epoch=9, errors=5.0
# epoch=10, errors=4.0
# epoch=11, errors=5.0
# epoch=12, errors=4.0
# epoch=13, errors=5.0
# epoch=14, errors=5.0
# epoch=15, errors=4.0
# epoch=16, errors=5.0
# epoch=17, errors=4.0
# epoch=18, errors=5.0
# epoch=19, errors=5.0
# epoch=20, errors=4.0
# epoch=21, errors=5.0
# epoch=22, errors=5.0
# epoch=23, errors=4.0
# epoch=24, errors=5.0
# epoch=25, errors=4.0
# epoch=26, errors=5.0
# epoch=27, errors=5.0
# epoch=28, errors=4.0
# epoch=29, errors=5.0
# epoch=30, errors=4.0
# epoch=31, errors=5.0
# epoch=32, errors=5.0
# epoch=33, errors=4.0
# epoch=34, errors=5.0
# epoch=35, errors=4.0
# epoch=36, errors=5.0
# epoch=37, errors=4.0
# epoch=38, errors=5.0
# epoch=39, errors=4.0
# epoch=40, errors=5.0
# epoch=41, errors=4.0
# epoch=42, errors=5.0
# ...

# %%
x1 = np.arange(0,12) 
x2 = (-theta[1]* x1 - theta[0])/ theta[2]

# %%
print(x1,x2)

# %%
plt.plot(train_nonseparable_p[:,0], train_nonseparable_p[:,1],'ob',label="train_nonseparable y = 1")
plt.plot(train_nonseparable_n[:,0], train_nonseparable_n[:,1],'or',label="train_nonseparable y = -1")
plt.plot(test_p[:,0], test_p[:,1],'og',label="test y = 1")
            errors = float(raw_list[1].replace("errors=",""))
            result_array.append([epoch,errors])
    return result_array

# %%
list_separable = raw_separable.split("\n")
list_inseparable = raw_inseparable.split("\n")
result_sep = collect(list_separable)
result_insep = collect(list_inseparable)
print(result_sep)
print(result_insep)
# Out:
# [[0.0, 2.0], [1.0, 1.0], [2.0, 0.0], [3.0, 0.0], [4.0, 0.0], [5.0, 0.0], [6.0, 0.0], [7.0, 0.0], [8.0, 0.0], [9.0, 0.0], [10.0, 0.0], [11.0, 0.0], [12.0, 0.0], [13.0, 0.0], [14.0, 0.0], [15.0, 0.0], [16.0, 0.0], [17.0, 0.0], [18.0, 0.0], [19.0, 0.0], [20.0, 0.0], [21.0, 0.0], [22.0, 0.0], [23.0, 0.0], [24.0, 0.0], [25.0, 0.0], [26.0, 0.0], [27.0, 0.0], [28.0, 0.0], [29.0, 0.0], [30.0, 0.0], [31.0, 0.0], [32.0, 0.0], [33.0, 0.0], [34.0, 0.0], [35.0, 0.0], [36.0, 0.0], [37.0, 0.0], [38.0, 0.0], [39.0, 0.0], [40.0, 0.0], [41.0, 0.0], [42.0, 0.0], [43.0, 0.0], [44.0, 0.0], [45.0, 0.0], [46.0, 0.0], [47.0, 0.0], [48.0, 0.0], [49.0, 0.0], [50.0, 0.0], [51.0, 0.0], [52.0, 0.0], [53.0, 0.0], [54.0, 0.0], [55.0, 0.0], [56.0, 0.0], [57.0, 0.0], [58.0, 0.0], [59.0, 0.0], [60.0, 0.0], [61.0, 0.0], [62.0, 0.0], [63.0, 0.0], [64.0, 0.0], [65.0, 0.0], [66.0, 0.0], [67.0, 0.0], [68.0, 0.0], [69.0, 0.0], [70.0, 0.0], [71.0, 0.0], [72.0, 0.0], [73.0, 0.0], [74.0, 0.0], [75.0, 0.0], [76.0, 0.0], [77.0,
# ...

# %%
plt.plot([x[0] for x in result_sep], [x[1] for x in result_sep],'-r',label="seperable")
plt.plot([x[0] for x in result_insep], [x[1] for x in result_insep],'-b',label="inseperable")
plt.xlim(0,99)
plt.legend(loc="upper right")
plt.savefig('2_6.png')
plt.show()

# %% [markdown]
# ### Online Part

# %%
#Problem 5
t1 = {"s":.5,"r":.5}
def sun(n,t1):
    if n == 1:
        return t1["s"]
    else:
        return sun(n-1,t1)*.75 + (1-sun(n-1,t1))*.2

# %%
 sun(4,t1)

# %%
# Problem 6
x1 = {0:.1,1:.3,2:0.6}
def prob(n,p,x1):
    if n == 1:
        return x1[p]
    else:
        if p == 0:
            return 0.3*prob(n-1,0,x1) + 0.37*prob(n-1,1,x1)+0.3*prob(n-1,2,x1)
        elif p == 1:
            return 0.5*prob(n-1,0,x1) + 0.33*prob(n-1,1,x1)+0.5*prob(n-1,2,x1)
        else:
            return 0.2*prob(n-1,0,x1) + 0.3*prob(n-1,1,x1)+0.2*prob(n-1,2,x1)

# %%
prob(3,1,x1)
