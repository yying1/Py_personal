# %%
## 2021-08-29
# Round D: Final Exam, with test 2 dataset

import numpy as np
from collections import OrderedDict

def match_pe_ps(pe_key,pe_val,ps_key,ps_val,s):
    pos = ""
    if pe_val<= s <= ps_key:
        if abs(s-pe_val) > abs(s-ps_key):
            match_s = ps_key
            match_e = ps_val
            if ps_key<s<ps_val:
                pos = "M"
            elif ps_key >= s:
                pos = "K"
        else:
            match_s = pe_key
            match_e = pe_val
            if pe_key<s<pe_val:
                pos = "M"
            elif pe_val <= s:
                pos = "V"
    elif s<pe_val:
        match_s = pe_key
        match_e = pe_val
        if pe_key>=s:
            pos = "K"
        else:
            pos = "M"
    elif ps_key<s:
        match_s = ps_key
        match_e = ps_val
        if ps_val<= s:
            pos = "V"
        else:
            pos = "M"
    return match_s,match_e,pos

f = open("ts1_input.txt")
# ff = open("1.txt","a")
cases = int(f.readline())

# cases = int(input())

for case in range(1):
    p_s,students = f.readline().split(" ")
#     p_s,students = input().split(" ")
    problems = {}
    assignments = []
    for s in range(int(p_s)):
        b,e = f.readline().split(" ")
#         b,e = input().split(" ")
        problems[int(b)] = int(e)
        # Creates a sorted dictionary (sorted by key)
#     problems = OrderedDict(sorted(problems.items()))
#         print(problems)

    student_skills = f.readline().split(" ")
#     student_skills = input().split(" ")
    student_skills = [int(x) for x in student_skills]
#     print(len(problems),len(student_skills))
    keyList=list(sorted(problems.keys()))
    for s in student_skills:
#         print(s)
        keyval = min(problems.items(), key=lambda x: abs(s - x[0]))
        valval = min(problems.items(), key=lambda x: abs(s - x[1]))
        if s == 520:
            print(keyval,valval)
        if keyval == valval:
            keyval =abs(keyval[0] - s)
            valval =abs(s-valval[0])
            ps_key_l = [k for k, v in problems.items() if abs(k-s)==keyval]
            pe_key_l = [k for k, v in problems.items() if abs(s-v)==valval]
            #print(type(ps_key_l),type(pe_key_l),len(ps_key_l),len(pe_key_l))
            if len(ps_key_l)>0:
                ps_key,ps_val = ps_key_l[0],problems[ps_key_l[0]]
            else:
                ps_key,ps_val = pe_key_l[0],problems[pe_key_l[0]]
            if len(pe_key_l)>0:
                pe_key,pe_val = pe_key_l[0],problems[pe_key_l[0]]
            else:
                pe_key,pe_val = ps_key_l[0],problems[ps_key_l[0]]
        else: 
            pe_key, pe_val = min(problems.items(), key=lambda x: abs(x[1]-s))
            ps_key, ps_val = min(problems.items(), key=lambda x: abs(s-x[0]))
        if s == 520:
            print(pe_key,pe_val,ps_key,ps_val)
        closest = 0
        match_s, match_e, pos = match_pe_ps(pe_key,pe_val,ps_key,ps_val,s)
        #print(match_s, match_e, pos)
        if pos == "K":
            del problems[match_s]
            if match_s < match_e:
                problems[match_s+1] = match_e
            closest = match_s
        elif pos == "V":
            if match_s < match_e:
                problems[match_s] = match_e-1
            else:
                del problems[match_s]
            closest = match_e
        elif pos == "M":
            if match_s <= s-1:
                problems[match_s] = s-1
            if s+1<= match_e:
                problems[s+1] = match_e
            closest = s
        assignments.append(closest)
    print(f'Case #{str(case+1)}: {" ".join(str(x) for x in assignments)}')
# Out:
# (521, 521) (521, 521)
# 521 521 521 521
# (531, 532) (531, 532)
# 531 532 531 532
# ...

# %%
mine = open("1.txt")
answer = open("ts1_output.txt")
for i in range(1):
    mline = mine.readline().strip()
    aline = answer.readline().strip()
    if mline == aline:
        continue
    else:
        print (mline)
        print(aline)
mlinel = mline.split(" ")
alinel = aline.split(" ")
for i in range(len(mlinel)):
    if mlinel[i] != alinel[i]:
        print (i,mlinel[i],alinel[i])
# Out:
# Case #1: 610 434 943 670 897 743 495 625 12 412 102 8 94 936 750 991 246 162 331 629 9 487 215 749 122 657 191 509 874 447 207 77 976 919 174 861 873 517 42 169 994 244 93 462 413 760 948 297 29 623 322 75 265 414 342 392 46 768 123 446 955 448 329 405 377 577 993 831 114 317 116 742 161 393 884 684 889 153 373 566 166 864 56 516 859 351 383 819 888 668 318 616 690 565 776 303 428 367 256 91 315 124 264 662 390 129 470 378 330 463 469 26 807 391 157 875 137 564 415 713 908 583 136 635 347 876 117 617 637 316 187 165 194 693 486 526 697 497 885 11 128 692 802 913 935 528 417 622 263 925 149 235 167 934 79 343 529 84 609 302 38 521 159 243 698 550 198 92 914 614 902 452 860 145 87 951 451 792 361 299 647 28 990 959 83 645 386 858 518 748 468 877 626 285 464 63 39 320 772 449 747 57 573 627 65 928 952 25 10 545 118 380 53 121 783 138 620 389 131 388 58 699 262 261 301 41 206 251 737 450 621 542 714 152 232 992 160 467 222 933 135 421 769 847 696 86 40 319 823 253 728 981 183 52 820 770 
# ...

# %%
Case #1: 610 434 943 670 897 743 495 625 12 412 102 8 94 936 750 991 246 162 331 629 9 487 215 749 122 657 191 509 874 447 207 77 976 919 174 861 873 517 42 169 994 244 93 462 413 760 948 297 29 623 322 75 265 414 342 392 46 768 123 446 955 448 329 405 377 577 993 831 114 317 116 742 161 393 884 684 889 153 373 566 166 864 56 516 859 351 383 819 888 668 318 616 690 565 776 303 428 367 256 91 315 124 264 662 390 129 470 378 330 463 469 26 807 391 157 875 137 564 415 713 908 583 136 635 347 876 117 617 637 316 187 165 194 693 486 526 697 497 885 11 128 692 802 913 935 528 417 622 263 925 149 235 167 934 79 343 529 84 609 302 38 521 159 243 698 550 198 92 914 614 902 452 860 145 87 951 451 792 361 299 647 28 990 959 83 645 386 858 518 748 468 877 626 285 464 63 39 320 772 449 747 57 573 627 65 928 952 25 10 545 118 380 53 121 783 138 620 389 131 388 58 699 262 261 301 41 206 251 737 450 621 542 714 152 232 992 160 467 222 933 135 421 769 847 696 86 40 319 823 253 728 981 183 52 820 770 604 296 54 433 346 221 62 132 848 546 954 563 719 387 193 45 127 64 857 918 168 416 37 892 669 519 771 917 924 44 628 661 432 830 208 791 855 878 901 958 418 